# %%
# !pip install "wetland_v[lidar,raster,speed] @ git+https://github.com/JaweedNazary/wetland_v.git"

# %%
# !git clone https://github.com/JaweedNazary/wetland_v
# !cd wetland_v
# !pip install -e ".[lidar,raster,speed]"
# Out:
# Cloning into 'wetland_v'...
# Obtaining file:///C:/Users/jawee/Codes/GitHub/lidar_land
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.24 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (2.3.5)
# Requirement already satisfied: pandas>=2.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (2.3.3)
# Requirement already satisfied: scipy>=1.10 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (1.17.0)
# Requirement already satisfied: geopandas>=0.14 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (1.1.2)
# Requirement already satisfied: shapely>=2.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (2.1.2)
# Requirement already satisfied: pyproj>=3.6 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (3.7.2)
# Requirement already satisfied: requests>=2.31 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (2.32.5)
# Requirement already satisfied: matplotlib>=3.7 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (3.10.8)
# Requirement already satisfied: plotly>=5.18 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (6.5.1)
# Requirement already satisfied: rich>=13.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (14.2.0)
# Requirement already satisfied: laspy>=2.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (2.7.0)
# Requirement already satisfied: pdal>=3.4 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (3.4.5)
# Requirement already satisfied: rasterio>=1.3 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (1.4.4)
# Requirement already satisfied: numba>=0.59 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v==0.1.0) (0.63.1)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from geopandas>=0.14->wetland_v==0.1.0) (0.12.1)
# Requirement already satisfied: packaging in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from geopandas>=0.14->wetland_v==0.1.0) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v==0.1.0) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v==0.1.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v==0.1.0) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from numba>=0.59->wetland_v==0.1.0) (0.46.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from pandas>=2.0->wetland_v==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from pandas>=2.0->wetland_v==0.1.0) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from plotly>=5.18->wetland_v==0.1.0) (2.15.0)
# Requirement already satisfied: certifi in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from pyogrio>=0.7.2->geopandas>=0.14->wetland_v==0.1.0) (2026.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7->wetland_v==0.1.0) (1.17.0)
# Requirement already satisfied: affine in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v==0.1.0) (2.4.0)
# Requirement already satisfied: attrs in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v==0.1.0) (25.4.0)
# Requirement already satisfied: click!=8.2.*,>=4.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v==0.1.0) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v==0.1.0) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v==0.1.0) (1.1.1.2)
# Requirement already satisfied: colorama in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from click!=8.2.*,>=4.0->rasterio>=1.3->wetland_v==0.1.0) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from requests>=2.31->wetland_v==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from requests>=2.31->wetland_v==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from requests>=2.31->wetland_v==0.1.0) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rich>=13.0->wetland_v==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rich>=13.0->wetland_v==0.1.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.0->wetland_v==0.1.0) (0.1.2)
# Building wheels for collected packages: wetland_v
#   Building editable for wetland_v (pyproject.toml): started
#   Building editable for wetland_v (pyproject.toml): finished with status 'done'
#   Created wheel for wetland_v: filename=wetland_v-0.1.0-0.editable-py3-none-any.whl size=2444 sha256=1093fba6d12cc85cb224b9126773548c7f01af0f6ee926e2c21fa5c826c7d189
#   Stored in directory: C:\Users\jawee\AppData\Local\Temp\pip-ephem-wheel-cache-fa8gndwp\wheels\44\24\74\72e7d25d03ac3094040e0e75a60241a4d6bcc59bf0c82ed2c6
# Successfully built wetland_v
# Installing collected packages: wetland_v
#   Attempting uninstall: wetland_v
#     Found existing installation: wetland_v 0.1.0
#     Uninstalling wetland_v-0.1.0:
#       Successfully uninstalled wetland_v-0.1.0
# Successfully installed wetland_v-0.1.0

# %%
# Show project documentation
from IPython.display import Markdown, display
display(Markdown(open("wetland_v/README.md").read()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Show project documentation
#       2 from IPython.display import Markdown, display
# ----> 3 display(Markdown(open("wetland_v/README.md").read()))
#
# File ~\anaconda3\envs\HydroINT\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wetland_v/README.md'

# %%
from wetland_v.usgs_3dep import load_3dep_index
from wetland_v.crs import gcs_to_proj
from wetland_v.get_years import get_available_years
from wetland_v.lidar import get_lidar_points_around_geometry_3857
from wetland_v.plot import plot_lidar
from wetland_v.crawl_trace import Crawl_Trace



index = load_3dep_index()

# %%
index.names
index.urls
index.counts
index.geometries_gcs
index.geometries_3857
# index.years_from_name_last4

# %%
xc = -92.2790255
yc = 38.9815258

point_geom = Point(xc, yc)
point_geom = gcs_to_proj(point_geom)
print(f'xc = {xc}, yc = {yc}')
# Out:
# xc = -92.2790255, yc = 38.9815258

# %%
point_geom.y
# Out:
# 4719025.647314158

# %%
index = load_3dep_index()
years = get_available_years(point_geom, index)
years

# %%
import time

st = time.time()

pts = get_lidar_points_around_geometry_3857(
    point_geom,
    index,
    buffer_distance=500,
    res=1,
    out_name="las",
    prefer_year=2009,
)

et = time.time()

print(f"elapsed time = {et - st:.2f} sec")

g_points = pts.ground_xyz
v_points = pts.veg_xyz
w_points = pts.water_xyz
all_points = pts.all_xyz
r = pts.most_recent_year
e = pts.las_path

# %%
g_points.T[2]

# %%
fig = plot_lidar(pts, plot_vegetation= True)
fig.show()

# %%
import time
st = time.time()
# k +=5
location = (point_geom.x, point_geom.y)
p_gdf, l_gdf, sampled_points = Crawl_Trace(location, 
                        N = 100, 
                        min_height=0.10, 
                        max_height = 20.0, 
                        window_size = (50, 5), 
                        D = 25, 
                        r = 20,  
                        resolution = 5.0,
                        method = 1, random_seed = 59, sigma = 1.0)


et = time.time()
print(f' elapsed time = {et - st:0.2f} sec')
# Out:
# Downloading LiDAR data...
# Crawling on the landscape...
# Tracing features of interest...
# Tracing  ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃  feature 100 out of 100.00,     100.00 %Crawling and tracing processes are successfully compeleted.
#  elapsed time = 46.57 sec

# %%
from wetland_v.plot import plot_features

fig = plot_features(sampled_points, p_gdf, method = 1, color = "red")
fig.show()

# %%
st = time.time()
# k +=5
location = (point_geom.x, point_geom.y)
p_gdf_channel, l_gdf, sampled_points = Crawl_Trace(location, 
                        N = 100, 
                        min_height=0.10, 
                        max_height = 20.0, 
                        window_size = (50, 5), 
                        D = 25, 
                        r = 20,  
                        resolution = 5.0,
                        method = 2, random_seed = 59, sigma = 1.0)


et = time.time()
print(f' elapsed time = {et - st:0.2f} sec')
# Out:
# Downloading LiDAR data...
# Crawling on the landscape...
# Tracing features of interest...
# Tracing  ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃  feature 100 out of 100.00,     100.00 %Crawling and tracing processes are successfully compeleted.
#  elapsed time = 31.43 sec

# %%
fig = plot_features(sampled_points, p_gdf_channel, method = 2, color = "blue")
fig.show()
