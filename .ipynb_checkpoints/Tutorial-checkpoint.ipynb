# %%
# !pip install "wetland_v[lidar,raster,speed] @ git+https://github.com/JaweedNazary/wetland_v.git"
# Out:
# Collecting wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git (from wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git)
#   Cloning https://github.com/JaweedNazary/wetland_v.git to c:\users\jawee\appdata\local\temp\pip-install-tmw_7a56\wetland-v_a399807422d94eaead74c77c484b54fd
#   Resolved https://github.com/JaweedNazary/wetland_v.git to commit a908349f4418a0c3b8570a7e158b60efdc7756e0
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.24 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.3.5)
# Requirement already satisfied: pandas>=2.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.3.3)
# Requirement already satisfied: scipy>=1.10 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (1.17.0)
# Requirement already satisfied: geopandas>=0.14 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (1.1.2)
# Requirement already satisfied: shapely>=2.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.1.2)
# Requirement already satisfied: pyproj>=3.6 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (3.7.2)
# Requirement already satisfied: requests>=2.31 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.32.5)
# Requirement already satisfied: matplotlib>=3.7 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (3.10.8)
# Requirement already satisfied: plotly>=5.18 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (6.5.1)
# Requirement already satisfied: rich>=13.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (14.2.0)
# Requirement already satisfied: laspy>=2.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.7.0)
# Requirement already satisfied: pdal>=3.4 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (3.4.5)
# Requirement already satisfied: rasterio>=1.3 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (1.4.4)
# Requirement already satisfied: numba>=0.59 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (0.63.1)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from geopandas>=0.14->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (0.12.1)
# Requirement already satisfied: packaging in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from geopandas>=0.14->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from numba>=0.59->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (0.46.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from pandas>=2.0->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from pandas>=2.0->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from plotly>=5.18->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.15.0)
# Requirement already satisfied: certifi in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from pyogrio>=0.7.2->geopandas>=0.14->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2026.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (1.17.0)
# Requirement already satisfied: affine in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.4.0)
# Requirement already satisfied: attrs in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (25.4.0)
# Requirement already satisfied: click!=8.2.*,>=4.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rasterio>=1.3->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (1.1.1.2)
# Requirement already satisfied: colorama in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from click!=8.2.*,>=4.0->rasterio>=1.3->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from requests>=2.31->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from requests>=2.31->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from requests>=2.31->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rich>=13.0->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from rich>=13.0->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jawee\anaconda3\envs\hydroint\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.0->wetland_v@ git+https://github.com/JaweedNazary/wetland_v.git->wetland_v[lidar,raster,speed]@ git+https://github.com/JaweedNazary/wetland_v.git) (0.1.2)
# Building wheels for collected packages: wetland_v
#   Building wheel for wetland_v (pyproject.toml): started
#   Building wheel for wetland_v (pyproject.toml): finished with status 'done'
#   Created wheel for wetland_v: filename=wetland_v-0.1.0-py3-none-any.whl size=14029 sha256=699c3fc04dd68760399bec03aa3b36a357a6e676c119dd15606eb22e92651171
#   Stored in directory: C:\Users\jawee\AppData\Local\Temp\pip-ephem-wheel-cache-luy4_mk0\wheels\93\34\e1\9b868efe8daef1552c7c050d89a3ad071a15d9b83bb17f0dcf
# Successfully built wetland_v
# Installing collected packages: wetland_v
#   Attempting uninstall: wetland_v
#     Found existing installation: wetland_v 0.1.0
#     Uninstalling wetland_v-0.1.0:
#       Successfully uninstalled wetland_v-0.1.0
# Successfully installed wetland_v-0.1.0
#   Running command git clone --filter=blob:none --quiet https://github.com/JaweedNazary/wetland_v.git 'C:\Users\jawee\AppData\Local\Temp\pip-install-tmw_7a56\wetland-v_a399807422d94eaead74c77c484b54fd'

# %%
# !git clone https://github.com/JaweedNazary/wetland_v
# !cd wetland_v
# !pip install -e ".[lidar,raster,speed]"

# %%
from wetland_v.usgs_3dep import load_3dep_index

index = load_3dep_index()

# %%
index.names
index.urls
index.counts
index.geometries_gcs
index.geometries_3857
# index.years_from_name_last4
# Out:
# 0       MULTIPOLYGON (((-17324357 8065255.4, -17321357...
# 1       MULTIPOLYGON (((-15726957 10940703, -15721457 ...
# 2       MULTIPOLYGON (((-16111039 9256091, -16109039 9...
# 3       MULTIPOLYGON (((-16398283 9531247.4, -16392283...
# 4       MULTIPOLYGON (((-15210725 8005983.2, -15207725...
#                               ...
# 2230    MULTIPOLYGON (((-12298782 5647656.1, -12296782...
# 2231    MULTIPOLYGON (((-12242434 5620878.9, -12236934...
# 2232    MULTIPOLYGON (((-12334873 5592680.8, -12334373...
# 2233    MULTIPOLYGON (((-12349489 5545766.1, -12347489...
# 2234    MULTIPOLYGON (((-12359282 5463696.6, -12341282...
# Length: 2235, dtype: geometry

# %%
from shapely.geometry import Point
from wetland_v.crs import gcs_to_proj

xc = -92.2790255
yc = 38.9815258

point_geom = Point(xc, yc)
point_geom = gcs_to_proj(point_geom)
print(f'xc = {xc}, yc = {yc}')
# Out:
# xc = -92.2790255, yc = 38.9815258

# %%
point_geom.y
# Out:
# 4719025.647314158

# %%
from wetland_v.get_years import get_available_years

index = load_3dep_index()
years = get_available_years(point_geom, index)
years
# Out:
# [9, 17]

# %%
from wetland_v.lidar import get_lidar_points_around_geometry_3857
import time
st = time.time()

g_points, v_points, w_points, nym , r = get_lidar_points_around_geometry_3857(point_geom, 
                                                                         index,
                                                                         buffer_distance = 1000, 
                                                                         res =2, 
                                                                         out_name = "las",
                                                                         prefer_year=17)


et = time.time()

print(f'elapsed time = {et- st:.2f} sec')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 from wetland_v.lidar import get_lidar_points_around_geometry_3857
#       2 import time
#       3 st = time.time()
#
# ImportError: cannot import name 'get_lidar_points_around_geometry_3857' from 'wetland_v.lidar' (C:\Users\jawee\anaconda3\envs\HydroINT\Lib\site-packages\wetland_v\lidar.py)

# %%
import wetland_v.lidar as L
print("Loaded lidar module from:", L.__file__)
print([name for name in dir(L) if "lidar" in name.lower()])
# Out:
# Loaded lidar module from: C:\Users\jawee\anaconda3\envs\HydroINT\Lib\site-packages\wetland_v\lidar.py
# ['LidarPoints', '_require_lidar_deps', 'get_lidar_points_around_geometry']
